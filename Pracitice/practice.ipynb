# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz as f
# Out:
# C:\Users\Sohai\New folder\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
l=[27,28,29,30,31]
d={"Sohaib":l,"Anas":l}
dates=pd.date_range("01-20-2018","01-24-2018")
data=pd.DataFrame(d,index=dates)
data
# Out:
#             Sohaib  Anas
# 2018-01-20      27    27
# 2018-01-21      28    28
# 2018-01-22      29    29
# 2018-01-23      30    30
# 2018-01-24      31    31

# %%
data["Zaid"]=l
data
# Out:
#             Sohaib  Anas  Zaid
# 2018-01-20      27    27    27
# 2018-01-21      28    28    28
# 2018-01-22      29    29    29
# 2018-01-23      30    30    30
# 2018-01-24      31    31    31

# %%
file=pd.read_csv("Election data 2018.csv")
file
# Out:
#      District                     Seat Constituency_title  \
# 0     Chitral                  Chitral               NA-1
# 1     Chitral                  Chitral               NA-1
# 2     Chitral                  Chitral               NA-1
# 3     Chitral                  Chitral               NA-1
# 4     Chitral                  Chitral               NA-1
# 5     Chitral                  Chitral               NA-1
# 6     Chitral                  Chitral               NA-1
# 7     Chitral                  Chitral               NA-1
# 8     Chitral                  Chitral               NA-1
# 9     Chitral                  Chitral               NA-1
# 10    Chitral                  Chitral               NA-1
# 11       Swat                   Swat-I              NA-2
# 12       Swat                   Swat-I              NA-2
# 13       Swat                   Swat-I              NA-2
# 14       Swat                   Swat-I              NA-2
# ...

# %%
len(file)
# Out:
# 3167

# %%
file[file.District=="Lasbela"]
# Out:
#      District                Seat Constituency_title           Candidate_Name  \
# 3154  Lasbela  Lasbela-cum-Gwadar             NA-272             Allah Bakhsh
# 3155  Lasbela  Lasbela-cum-Gwadar             NA-272           Jam Jamal Khan
# 3156  Lasbela  Lasbela-cum-Gwadar             NA-272            Shakeel Ahmed
# 3157  Lasbela  Lasbela-cum-Gwadar             NA-272                Attaullah
# 3158  Lasbela  Lasbela-cum-Gwadar             NA-272                Ali Ahmed
# 3159  Lasbela  Lasbela-cum-Gwadar             NA-272               Ali Baloch
# 3160  Lasbela  Lasbela-cum-Gwadar             NA-272            Ghulam Sarwar
# 3161  Lasbela  Lasbela-cum-Gwadar             NA-272     Ghulam Mustafa Malik
# 3162  Lasbela  Lasbela-cum-Gwadar             NA-272   Mohammad Akhtar Mengal
# 3163  Lasbela  Lasbela-cum-Gwadar             NA-272  Mohammad Aslam Bhootani
# 3164  Lasbela  Lasbela-cum-Gwadar             NA-272           Mohammad Akram
# ...

# %%
file[file.Constituency_title=="NA-247"]
# Out:
#       District              Seat Constituency_title           Candidate_Name  \
# 2726  Karachi   Karachi South-II             NA-247          Afan ullah khan
# 2727  Karachi   Karachi South-II             NA-247      aftab hussain lakho
# 2728  Karachi   Karachi South-II             NA-247         jawed iqbal khan
# 2729  Karachi   Karachi South-II             NA-247               deedar ali
# 2730  Karachi   Karachi South-II             NA-247                raj kumar
# 2731  Karachi   Karachi South-II             NA-247     syed zaman ali jafri
# 2732  Karachi   Karachi South-II             NA-247      syed mansoob hussan
# 2733  Karachi   Karachi South-II             NA-247           arif ur rehmen
# 2734  Karachi   Karachi South-II             NA-247              abdul habib
# 2735  Karachi   Karachi South-II             NA-247                ali nawab
# 2736  Karachi   Karachi South-II             NA-247               abdul aziz
# ...

# %%
file[file.Constituency_title=="NA-247"].count()
# Out:
# District              21
# Seat                  21
# Constituency_title    21
# Candidate_Name        21
# Party                 21
# dtype: int64

# %%
file[file.Candidate_Name=="Imran Khan"]
# Out:
#         District           Seat Constituency_title Candidate_Name  \
# 507  Tribal Area  Tribal Area-5              NA-44     Imran Khan
#
#                     Party
# 507  Awami National Party

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
j=pd.read_csv("Import_User_Sample_en.csv")
j
# Out:
#              User Name First Name Last Name     Display Name   Job Title  \
# 0    chris@contoso.com      Chris     Green      Chris Green  IT Manager
# 1      ben@contoso.com        Ben   Andrews      Ben Andrews  IT Manager
# 2    david@contoso.com      David  Longmuir   David Longmuir  IT Manager
# 3  cynthia@contoso.com    Cynthia     Carey    Cynthia Carey  IT Manager
# 4  melissa@contoso.com    Melissa   MacBeth  Melissa MacBeth  IT Manager
#
#                Department  Office Number  Office Phone  Mobile Phone  \
# 0  Information Technology         123451  123-555-1211  123-555-6641
# 1  Information Technology         123452  123-555-1212  123-555-6642
# 2  Information Technology         123453  123-555-1213  123-555-6643
# 3  Information Technology         123454  123-555-1214  123-555-6644
# 4  Information Technology         123455  123-555-1215  123-555-6645
#
#             Fax          Address     City State or Province  \
# ...

# %%
d=[1,2,3,4,5]
pd.Series(d)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
date=pd.date_range("1-6-2018","1-20-2018")
date
# Out:
# DatetimeIndex(['2018-01-06', '2018-01-07', '2018-01-08', '2018-01-09',
#                '2018-01-10', '2018-01-11', '2018-01-12', '2018-01-13',
#                '2018-01-14', '2018-01-15', '2018-01-16', '2018-01-17',
#                '2018-01-18', '2018-01-19', '2018-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
a=[i for i in range(15)]
b={"Sohaib":a,"Anas":a}
c=pd.DataFrame(b,index=date)
c
# Out:
#             Sohaib  Anas
# 2018-01-06       0     0
# 2018-01-07       1     1
# 2018-01-08       2     2
# 2018-01-09       3     3
# 2018-01-10       4     4
# 2018-01-11       5     5
# 2018-01-12       6     6
# 2018-01-13       7     7
# 2018-01-14       8     8
# 2018-01-15       9     9
# 2018-01-16      10    10
# 2018-01-17      11    11
# 2018-01-18      12    12
# 2018-01-19      13    13
# 2018-01-20      14    14

# %%
d=pd.read_csv("table.csv")
d
# Out:
#                                                    Data       Unnamed: 1  \
# 0     6366 full-time workers in five North-Central S...              NaN
# 1                                     Recoded Variables              NaN
# 2                                    Usual Hours Worked  Education (yrs)
# 3                                                    40               13
# 4                                                    35               12
# 5                                                    70               11
# 6                                                    40               16
# 7                                                    38               12
# 8                                                    60               18
# 9                                                    40               13
# 10                                                   50                8
# 11                                                   40               11
# ...

# %%
d["Data"]
# Out:
# 0       6366 full-time workers in five North-Central S...
# 1                                       Recoded Variables
# 2                                      Usual Hours Worked
# 3                                                      40
# 4                                                      35
# 5                                                      70
# 6                                                      40
# 7                                                      38
# 8                                                      60
# 9                                                      40
# 10                                                     50
# 11                                                     40
# 12                                                     50
# 13                                                     45
# 14                                                     50
# 15                                                     50
# ...

# %%
d[d.Data=="Usual Hours Worked"]
# Out:
#                  Data       Unnamed: 1         Unnamed: 2 Unnamed: 3  \
# 2  Usual Hours Worked  Education (yrs)   Yearly Earnings        Race
#
#   Unnamed: 4             Unnamed: 5 Unnamed: 6       Unnamed: 7 Unnamed: 8  \
# 2        Sex  Usual Weekly Earnings      State  Month in Sample   A_GRSWK
#
#   Unnamed: 9     ...      Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 2  PMHRUSLT      ...           A_HGA      A_RACE       A_SEX     GMSTCEN
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20
# 2      H_MIS    WSAL_VAL          NaN          NaN          NaN          NaN
#
# [1 rows x 21 columns]

# %%
d[d["Data"]=="Recoded Variables"]
# Out:
#                 Data Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1  Recoded Variables        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7          Unnamed: 8 Unnamed: 9     ...       \
# 1        NaN        NaN  Original Variables        NaN     ...
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20
# 1         NaN          NaN          NaN          NaN
#
# [1 rows x 21 columns]

# %%
d[d["Unnamed: 15"]==1]
# Out:
# Empty DataFrame
# Columns: [Data, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20]
# Index: []
#
# [0 rows x 21 columns]

# %%
file[file.District=="Lasbela"]
# Out:
#      District                Seat Constituency_title           Candidate_Name  \
# 3154  Lasbela  Lasbela-cum-Gwadar             NA-272             Allah Bakhsh
# 3155  Lasbela  Lasbela-cum-Gwadar             NA-272           Jam Jamal Khan
# 3156  Lasbela  Lasbela-cum-Gwadar             NA-272            Shakeel Ahmed
# 3157  Lasbela  Lasbela-cum-Gwadar             NA-272                Attaullah
# 3158  Lasbela  Lasbela-cum-Gwadar             NA-272                Ali Ahmed
# 3159  Lasbela  Lasbela-cum-Gwadar             NA-272               Ali Baloch
# 3160  Lasbela  Lasbela-cum-Gwadar             NA-272            Ghulam Sarwar
# 3161  Lasbela  Lasbela-cum-Gwadar             NA-272     Ghulam Mustafa Malik
# 3162  Lasbela  Lasbela-cum-Gwadar             NA-272   Mohammad Akhtar Mengal
# 3163  Lasbela  Lasbela-cum-Gwadar             NA-272  Mohammad Aslam Bhootani
# 3164  Lasbela  Lasbela-cum-Gwadar             NA-272           Mohammad Akram
# ...

# %%
file[(file.District=="Lasbela")&(file.Party=="Independent")]
# Out:
#      District                Seat Constituency_title           Candidate_Name  \
# 3156  Lasbela  Lasbela-cum-Gwadar             NA-272            Shakeel Ahmed
# 3159  Lasbela  Lasbela-cum-Gwadar             NA-272               Ali Baloch
# 3160  Lasbela  Lasbela-cum-Gwadar             NA-272            Ghulam Sarwar
# 3161  Lasbela  Lasbela-cum-Gwadar             NA-272     Ghulam Mustafa Malik
# 3163  Lasbela  Lasbela-cum-Gwadar             NA-272  Mohammad Aslam Bhootani
#
#             Party
# 3156  Independent
# 3159  Independent
# 3160  Independent
# 3161  Independent
# 3163  Independent

# %%
pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
c["Zaid"]=a
c
# Out:
#             Sohaib  Anas  Zaid
# 2018-01-06       0     0     0
# 2018-01-07       1     1     1
# 2018-01-08       2     2     2
# 2018-01-09       3     3     3
# 2018-01-10       4     4     4
# 2018-01-11       5     5     5
# 2018-01-12       6     6     6
# 2018-01-13       7     7     7
# 2018-01-14       8     8     8
# 2018-01-15       9     9     9
# 2018-01-16      10    10    10
# 2018-01-17      11    11    11
# 2018-01-18      12    12    12
# 2018-01-19      13    13    13
# 2018-01-20      14    14    14

# %%
c.loc["2018-01-10",["Anas","Zaid"]]
# Out:
# Anas    4
# Zaid    4
# Name: 2018-01-10 00:00:00, dtype: int64

# %%
c.iloc[3]
# Out:
# Sohaib    3
# Anas      3
# Zaid      3
# Name: 2018-01-09 00:00:00, dtype: int64

# %%
e=[i for i in range(15,30)]
f={"Sohaib":e,"Wajeeh":e}
g=pd.DataFrame(f,index=date)
g
# Out:
#             Sohaib  Wajeeh
# 2018-01-06      15      15
# 2018-01-07      16      16
# 2018-01-08      17      17
# 2018-01-09      18      18
# 2018-01-10      19      19
# 2018-01-11      20      20
# 2018-01-12      21      21
# 2018-01-13      22      22
# 2018-01-14      23      23
# 2018-01-15      24      24
# 2018-01-16      25      25
# 2018-01-17      26      26
# 2018-01-18      27      27
# 2018-01-19      28      28
# 2018-01-20      29      29

# %%
c+g
# Out:
#             Anas  Sohaib  Wajeeh  Zaid
# 2018-01-06   NaN      15     NaN   NaN
# 2018-01-07   NaN      17     NaN   NaN
# 2018-01-08   NaN      19     NaN   NaN
# 2018-01-09   NaN      21     NaN   NaN
# 2018-01-10   NaN      23     NaN   NaN
# 2018-01-11   NaN      25     NaN   NaN
# 2018-01-12   NaN      27     NaN   NaN
# 2018-01-13   NaN      29     NaN   NaN
# 2018-01-14   NaN      31     NaN   NaN
# 2018-01-15   NaN      33     NaN   NaN
# 2018-01-16   NaN      35     NaN   NaN
# 2018-01-17   NaN      37     NaN   NaN
# 2018-01-18   NaN      39     NaN   NaN
# 2018-01-19   NaN      41     NaN   NaN
# 2018-01-20   NaN      43     NaN   NaN

# %%
c-g
# Out:
#             Anas  Sohaib  Wajeeh  Zaid
# 2018-01-06   NaN     -15     NaN   NaN
# 2018-01-07   NaN     -15     NaN   NaN
# 2018-01-08   NaN     -15     NaN   NaN
# 2018-01-09   NaN     -15     NaN   NaN
# 2018-01-10   NaN     -15     NaN   NaN
# 2018-01-11   NaN     -15     NaN   NaN
# 2018-01-12   NaN     -15     NaN   NaN
# 2018-01-13   NaN     -15     NaN   NaN
# 2018-01-14   NaN     -15     NaN   NaN
# 2018-01-15   NaN     -15     NaN   NaN
# 2018-01-16   NaN     -15     NaN   NaN
# 2018-01-17   NaN     -15     NaN   NaN
# 2018-01-18   NaN     -15     NaN   NaN
# 2018-01-19   NaN     -15     NaN   NaN
# 2018-01-20   NaN     -15     NaN   NaN
